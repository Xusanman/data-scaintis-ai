# %% [markdown]
# # HDF5 formati

# %%
# kerakli fayllarni Gitdan import qilib olamiz
# !git clone https://github.com/Xusanman/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 45 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 7.17 MiB | 6.85 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# kerakli kutubxonani chaqirish
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('praktikum_datasets/uzbekistan.xlsx', index_col=0, names=['hudud', 'maydon', 'aholi'])
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df.to_excel("newuzb.xlsx")

# %%
obj = df.maydon
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_csv("uzmaydon.csv")

# %%
series = pd.read_csv("uzmaydon.csv", index_col='hudud').squeeze("columns")
series
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
series.to_excel("series_excel.xlsx")

# %%
df2 = pd.read_csv("praktikum_datasets/automobile_data.csv", sep=",", index_col='index')
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0
# ...                ...         ...              ...      ...
# 81                four          85               27   7975.0
# 82                four          52               37   7995.0
# 86                four         100               26   9995.0
# 87                four         114               23  12940.0
# 88                four         114               23  13415.0
#
# [61 rows x 9 columns]

# %%
df2.to_excel("sample_data/car_data.xlsx", index=False, columns=['company', 'body-style', 'price'])

# %%
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0
# ...                ...         ...              ...      ...
# 81                four          85               27   7975.0
# 82                four          52               37   7995.0
# 86                four         100               26   9995.0
# 87                four         114               23  12940.0
# 88                four         114               23  13415.0
#
# [61 rows x 9 columns]

# %%
hdfobj = pd.HDFStore("data.h5")

# %%
hdfobj.put('uztada', df)

# %%
hdfobj.put('cardata', df2)

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uztada']

# %%
hdfobj['cardata']
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0
# ...                ...         ...              ...      ...
# 81                four          85               27   7975.0
# 82                four          52               37   7995.0
# 86                four         100               26   9995.0
# 87                four         114               23  12940.0
# 88                four         114               23  13415.0
#
# [61 rows x 9 columns]

# %%
hdfobj = pd.HDFStore("data.h5")

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uztada']

# %%
hdfobj.close()

# %%
data = pd.read_hdf('data.h5', key="cardata")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1688/1393133780.py in <cell line: 0>()
# ----> 1 data = pd.read_hdf('data.h5', key="cardata")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     424             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     425
# --> 426         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     427         # can't auto open/close if we are using an iterator
#     428         # so delegate to the iterator
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     583         self._fletcher32 = fletcher32
#     584         self._filters = None
# --> 585         self.open(mode=mode, **kwargs)
#     586
#     587     def __fspath__(self) -> str:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     743             raise ValueError(msg)
#     744
# --> 745         self._handle = tables.open_file(self._path, self._mode, **kwargs)
#     746
#     747     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     304             # 'r' is incompatible with everything except 'r' itself
#     305             if mode == "r" and omode != "r":
# --> 306                 raise ValueError(
#     307                     "The file '%s' is already opened, but "
#     308                     "not in read-only mode (as requested)." % filename
#
# ValueError: The file 'data.h5' is already opened, but not in read-only mode (as requested).

# %%
data.to_hdf('data.h5', key="uzdata")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1688/3387470409.py in <cell line: 0>()
# ----> 1 data.to_hdf('data.h5', key="uzdata")
#
# NameError: name 'data' is not defined
