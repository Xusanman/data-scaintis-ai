# %% [markdown]
# # Pandas kutubxonasi
# # 2, 3-darslar. Faylga o'qish va yozish

# %% [markdown]
# 1. `!git clone https://github.com/Xusanman/praktikum_datasets` - ma'lumot va
# fayllarni GitHub dan nusxalash
#
# 2. **`pandas` kutubxonasi fayllar bilan ishlaydigan bir nechta funksiyalardan iborat:**
#
# 3. `read_csv` - vergul bilan ajratilgan jadval fayllarni o'qish uchun
#
# 4. `read_table` - probel (bo'sh joy) bilan ajratilgan jadval fayllarni o'qish uchun
# 5. `read_excel` - `xls` yoki `xlsx` formatidagi Excel fayllarni o'qish uchun
#
# 6. `read_clipboard` - ko'chirilgan (xotiradagi) jadvalni o'qish
#
# 7. `read_hdf` - HDF5 formatidagi fayllarni o'qish
#
# 8. `read_html` - HTML (web) sahifadagi barcha jadvallarni o'qish
#
# 9. `read_json` - JSON ma'lumotlarni o'qish
#
# 10. `read_pickle` - pickle formatidagi fayllarni o'qish
#
# 11. `read_sql` - SQL query dan qaytgan ma'lumotlarni o'qish (SQLAlchemy bilan ishlaydi)
#
# 12. `index_col=0` indexni berilgan columnga o'zgartiradi
# 13. `sep=","` belgilar bilan ajratilgan ma'lumotlarni ustunga ajratadi
# 14. `nrows=15` ko'rsatiladigan qatorlarni soni
# 15. `names=['hudud', 'maydon', 'aholi']` ustunlar nomlarini o'zgartirish
# 16. `.squeeze("columns")` DataFrayemni > Series obyektga aylantiradi (bunda jadval 2 ta ustundan iborat bo'lishi kerak)
# 17. `index=False` indexni faylga yozmaydi
# 18. `.to_excel, to_csv, to_html, to_sql` faylga yozish
